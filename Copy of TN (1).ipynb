# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Flatten

# Example data for classification/prediction task
# Replace this with your own dataset
X_train = np.random.random((1000, 10, 1))  # Example features (assuming a sequence of length 10 with 1 feature)
y_train = np.random.randint(2, size=(1000,))  # Example labels (binary classification)

# Convolutional Neural Network (CNN)
cnn_model = Sequential([
    Conv1D(32, 3, activation='relu', input_shape=(10, 1)),
    MaxPooling1D(2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the CNN model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 3ms/step - loss: 0.6962 - accuracy: 0.4850
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5160
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5180
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5360
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5370
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5370
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.5430
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5380
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.5530
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.5510
